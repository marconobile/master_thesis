# %%
import pickle

with open('new_filtered_dataset_from_all_structures', 'rb') as fp:
    suppl_filtered_4 = pickle.load(fp)
suppl_filtered_4
# Out:
# RDKit WARNING: [23:21:52] Enabling RDKit 2019.09.2 jupyter extensions
# ...
#  ...]

# %%
from rdkit import Chem
Chem.Draw.MolsToImage(suppl_filtered_4[:500])
# Out:
# <PIL.Image.Image image mode=RGBA size=100000x200 at 0x7FFB75DF7290>

# %%
print(len(suppl_filtered_4))
# Out:
# 6015
